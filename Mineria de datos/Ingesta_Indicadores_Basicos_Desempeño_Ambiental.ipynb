# %%
import pandas as pd

# %%
# Obtenemos la Data sobre Indicadores Básicos del Desempeño Ambiental - Residuos peligrosos

# Listamos las URL de las fuentes de datos origen, para poder realizar la ingesta
urls = [
    'http://dsiappsdev.semarnat.gob.mx/datos/indicadores/dambiental/Residuos%20peligrosos/volumen%20de%20residuos%20peligrosos%20reportado%20por%20empresas%20a%20semarnat.csv',
    'http://dsiappsdev.semarnat.gob.mx/datos/indicadores/dambiental/Residuos%20peligrosos/sitios%20con%20residuos%20peligrosos%20remediados%20o%20en%20remediacion.csv',
    'http://dsiappsdev.semarnat.gob.mx/datos/indicadores/dambiental/Residuos%20peligrosos/volumen%20fisico%20de%20produccion%20manufacturero%20y%20minero.csv',
    'http://dsiappsdev.semarnat.gob.mx/datos/indicadores/dambiental/Residuos%20peligrosos/auditorias%20ambientales.csv',
    'http://dsiappsdev.semarnat.gob.mx/datos/indicadores/dambiental/Residuos%20peligrosos/cumplimiento%20de%20normatividad%20en%20residuos%20peligrosos.csv',
    'http://dsiappsdev.semarnat.gob.mx/datos/indicadores/dambiental/Residuos%20peligrosos/sitios%20contaminados%20registrados.csv'
]

# %%
for url in urls:
    df = pd.read_csv(url)
    print(df.head())
# Out:
#          AÑO  GENERACION_ACUMULADA_(TONELADAS_ACUMULADAS_POR_PERIODO)
# 0  2004-2009                                         1699635.04
# 1  2004-2011                                         1920408.13
# 2  2004-2012                                         1958231.34
# 3  2004-2013                                         2035068.85
# 4  2004-2014                                         2193336.45
#     AÑO            TIPO_DE_SITIO  CANTIDAD_(NUMERO)
# 0  2008  Emergencias Ambientales                142
# 1  2008      Pasivos Ambientales                479
# 2  2008        Sitios Remediados                 76
# 3  2009  Emergencias Ambientales                135
# 4  2009      Pasivos Ambientales                465
#       AÑO         SECTOR  VOLUMEN_FISICO_(INDICE_DE_VOLUMEN_FISICO)
# 0  1993.0         Minero                                      102.0
# 1  1993.0  Manufacturero                                       65.0
# ...

# %%
# Ingesta
df_recolecion = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/residuos/Rubro8_Recoleccion_y_Transporte_de_residuos_peligrosos.csv')

# %%
df_recolecion.head()
# Out:
#   No.                                            Empresa  \
# 0   1  Servicios Industriales Ecologicos (Javier Maci...
# 1   2                          Juan Carlos Ibarra Torres
# 2   3                               Solver, S.A. de C.V.
# 3   4                Ingenieria y Ecologia, S.A. de C.V.
# 4   5          Industrias P. Kay de Mixico, S.A. de C.V.
#
#                                            Direccisn       Municipio  \
# 0                              Angel Gonzalez No. 11  Aguascalientes
# 1  Francisco Sarabia No. 314, Col. Altavista, C.P...  Aguascalientes
# 2  Meseta de Chema No. 2500, Col. Monte de los Ol...         Tijuana
# 3  Rmo fuerte y Felipe Angeles No. 599 Col. Vallarta        Mexicali
# 4  Calle de la Brea No. 3, Meseta de Chema, Col. ...         Tijuana
#
#    Clave Municipio           Estado  Clave Entidad           Telifono  \
# 0              1.0   Aguascalientes            1.0                NaN
# ...

# %%
# Ingesta: Inventario Nacional de Emisiones de Gases y Compuestos de Efecto Invernadero (INEGyCEI)

# %%
# Ordenamiento Ecológico del Territorio Modalidad Local
# URL: https://datos.gob.mx/busca/dataset/ordenamiento-ecologico-del-territorio-modalidad-local
df_ordeco = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/POET_local.csv', encoding='latin')

# %%
df_ordeco
# Out:
#       Año  Estado  Monto federal otorgado  Modalidad
# 0   2014.0  México           $3,018,296.00     Local
# 1   2014.0  Oaxaca           $3,576,200.00     Local
# 2      NaN     NaN                     NaN       NaN
# 3      NaN     NaN                     NaN       NaN
# 4      NaN     NaN                     NaN       NaN
# 5      NaN     NaN                     NaN       NaN
# 6      NaN     NaN                     NaN       NaN
# 7      NaN     NaN                     NaN       NaN
# 8      NaN     NaN                     NaN       NaN
# 9      NaN     NaN                     NaN       NaN
# 10     NaN     NaN                     NaN       NaN
# 11     NaN     NaN                     NaN       NaN
# 12     NaN     NaN                     NaN       NaN
# 13     NaN     NaN                     NaN       NaN
# 14     NaN     NaN                     NaN       NaN
# 15     NaN     NaN                     NaN       NaN
# 16     NaN     NaN                     NaN       NaN
# ...

# %%
# Ordenamiento Ecológico del Territorio Modalidad Regional
# URL: https://datos.gob.mx/busca/dataset/ordenamiento-ecologico-del-territorio-modalidad-regional
df_ord_eco_regional = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/POET_regional.csv', encoding='latin')

# %%
df_ord_eco_regional
# Out:
#     Año      Estado  Monto federal otorgado   Modalidad
# 0   2014      Colima           $1,100,000.00   Regional
# 1   2014     Durango             $899,980.27   Regional
# 2   2014     Hidalgo           $5,985,000.00   Regional
# 3   2014     Jalisco           $3,092,421.70   Regional
# 4   2014      México           $8,470,404.00   Regional
# 5   2014      Oaxaca           $1,190,000.00  Regional
# 6   2014     Sinaloa           $2,000,000.00   Regional
# 7   2014     Tabasco           $2,478,038.70   Regional
# 8   2015     Chiapas             $538,800.00   Regional
# 9   2015      Colima           $1,078,000.00   Regional
# 10  2015     Hidalgo           $4,116,000.00   Regional
# 11  2015     Jalisco          $10,878,018.66   Regional
# 12  2015      México           $9,127,200.00   Regional
# 13  2015  Tamaulipas           $4,300,057.24   Regional

# %%
# Programa Sectorial de Medio Ambiente y Recursos Naturales
# https://datos.gob.mx/busca/dataset/programa-sectorial-de-medio-ambiente-y-recursos-naturales
df_programa_sectorial = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/promarnat_2013_2018.csv', encoding='latin')

# %%
df_programa_sectorial
# Out:
#     No. del Indicador  Objetivo No.  \
# 0                   1             1
# 1                   2             1
# 2                   3             1
# 3                   4             2
# 4                   5             2
# 5                   6             2
# 6                   7             3
# 7                   8             3
# 8                   9             3
# 9                  10             4
# 10                 10             4
# 11                 11             4
# 12                 12             4
# 13                 13             5
# 14                 14             5
# 15                 15             5
# 16                 16             6
# 17                 17             6
#
#                                 Nombre del indicador: Línea base 2013  \
# 0   Valor de la Producción de los Bienes y Servici...            1.07
# 1                               Intensidad de carbono           50.07
# ...

# %%
# Indicadores clave - Residuos
# https://datos.gob.mx/busca/dataset/indicadores-clave--residuos
df_ind_residuos = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/indicadores/clave/residuos%20solidos%20urbanos%20depuestos%20sin%20control.csv')

# %%
df_ind_residuos
# Out:
#      AÑO  VOLUMEN_DEPUESTO_SIN_CONTROL
# 0   1997                      16655.12
# 1   1998                      12945.92
# 2   1999                      13286.45
# 3   2000                      13096.47
# 4   2001                      12141.93
# 5   2002                      12182.37
# 6   2003                      10954.80
# 7   2004                      11401.84
# 8   2005                      11344.00
# 9   2006                      11423.40
# 10  2007                      10971.30
# 11  2008                      10880.00
# 12  2009                      10725.00
# 13  2010                      10123.40
# 14  2011                       9519.40
# 15  2012                       8679.61

# %%
# Agua Residual que recibe tratamiento
# Agua residual que recibe tratamiento por entidad federativa
# https://datos.gob.mx/busca/dataset/agua-residual-que-recibe-tratamiento
df_agua_fed = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/Tratamiento_X_ent_federativa.csv')

# %%
df_agua_fed
# Out:
#       ENTIDAD FEDERATIVA   AÑO  CAUDAL / GENERADO  (litros por segundo)  \
# 0         Aguascalientes  2009                                     2744
# 1      Baja California    2009                                     6040
# 2    Baja California Sur  2009                                     1960
# 3               Campeche  2009                                     2042
# 4                Chiapas  2009                                     6137
# ..                   ...   ...                                      ...
# 155           Tamaulipas  2013                                     7931
# 156             Tlaxcala  2013                                     1825
# 157             Veracruz  2013                                    14183
# 158              Yucatán  2013                                     4925
# 159            Zacatecas  2013                                     4634
#
#      CAUDAL / TRATADO  (litros por segundo)  TRATADO/ GENERADO (porcentaje)
# ...

# %%
# Agua Residual que recibe tratamiento
# Agua residual que recibe tratamiento
# https://datos.gob.mx/busca/dataset/agua-residual-que-recibe-tratamiento
df_agua_tratamiento = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/Tratamiento.csv')

# %%
df_agua_tratamiento
# Out:
#      AÑO  MUNICIPAL / GENERADO (metros cúbicos/segundo)  \
# 0   1998                                         239.00
# 1   1999                                         239.00
# 2   2000                                         250.00
# 3   2001                                         252.00
# 4   2002                                         252.00
# 5   2003                                         255.30
# 6   2004                                         255.17
# 7   2005                                         265.63
# 8   2006                                         242.10
# 9   2007                                         242.81
# 10  2008                                         235.84
# 11  2009                                         237.46
# 12  2010                                         235.08
# 13  2011                                         236.35
# 14  2012                                         229.74
# 15  2013                                         230.62
#
# ...

# %%
# Almacenamiento (acopio)
# https://datos.gob.mx/busca/dataset/almacenamiento-acopio
df_acopio = pd.read_csv('http://dsiappsdev.semarnat.gob.mx/datos/residuos/Rubro9_Almacenamiento_y_Acopio_de_residuos_peligrosos.csv')
df_acopio
# Out:
#      No.                                            Empresa  \
# 0       1                        Juan Antonio Ibarra Torres
# 1       2    Suministros Ambientales Mexicanos, S.A de C.V.
# 2       3     VLS Recovery Services de Mixico, S.A. de C.V.
# 3       4             Pochteca Materias Primas, S.A. de C.V
# 4       5  Grupo Ambiental Del Noroeste, S. de R.L. de C.V.
# ..    ...                                               ...
# 462   463                            Inlubsa, S.A. de C.V.
# 463   464                        Protec Medica S.A de C.V.
# 464   465                     Sara Abigail Hernandez Urenda
# 465   466              Repuestos de Zacatecas, S.A. de C.V.
# 466   467   Fidencio Del Rio Esparza Sucesores S.A. de C.V.
#
#                                              Direccisn       Municipio  \
# 0    Francisco Sarabia, No. 314, col Altavista, C.P...  Aguascalientes
# 1    Calle Cuyamaca Lote 17-B,Colonia Plutarco Elei...        Mexicali
# ...

# %%
df_acopio.Estado.unique()
# Out:
# array(['Aguascalientes', 'Baja California', ' Baja California',
#        'Baja California Sur', 'Campeche', 'Chihuahua', 'Chihuahua ',
#        'Coahuila ', 'Colima', 'Ciudad de Mixico', 'Ciudad de Mixico ',
#        'Durango', 'Guanajuato', 'Guanajuato ', 'Guerrero', 'Hidalgo',
#        'Hidalgo ', 'Jalisco', 'JALISCO', 'Mixico', 'Michoacan de Ocampo',
#        'Morelos', 'Nayarit', 'Nuevo Lesn', 'Miguel Hidalgo  ',
#        'Nuevo Lesn ', 'Oaxaca', 'Puebla', 'Queritaro', 'San Luis Potosm',
#        'Tabasco', 'Tamaulipas', 'Tlaxcala',
#        'Veracruz de Ignacio de la Llave', 'Veracruz', 'Yucatan ',
#        'Yucatan', 'Zacatecas '], dtype=object)

# %%
# Superficie de Conservación Recuperada (SEDEMA)
# https://datos.cdmx.gob.mx/dataset/indicadores-monitor-estadistico-de-la-ciudad-de-mexico
df_conservacion = pd.read_csv('https://datos.cdmx.gob.mx/dataset/5b938119-7d49-491f-9eba-09cd4f7241b5/resource/bfb72f62-a09e-43c2-8035-1794063fc0d0/download/superficie-conservacion.csv')

# %%
df_conservacion
# Out:
#         fecha  ciudad_de_mexico
# 0  2016-01-01            113.25
# 1  2017-01-01            117.85
# 2  2018-01-01            134.45
# 3  2019-01-01            221.65
# 4  2020-01-01            405.29
# 5  2021-01-01            492.86

# %% [markdown]
# # Red Manual de Monitoreo Atmosférico (REDMA)
#
# La Red de Meteorología y Radiación Solar (REDMET) es el subsistema del Sistema de Monitoreo Atmosférico de la Ciudad de México (SIMAT) que realiza mediciones periódicas cada 6 días de partículas suspendidas totales (PST), partículas menores a 10 micrómetros, plomo en partículas suspendidas totales (Pb PST), partículas menores a 2.5 micrómetros. (PM25)
#
# Link [https://datos.cdmx.gob.mx/dataset/redma](https://datos.cdmx.gob.mx/dataset/redma)

# %%
df_redma = pd.read_csv('https://datos.cdmx.gob.mx/dataset/1729ac65-a3c5-46ab-a851-71a983795598/resource/12769c73-8bb9-4244-ad60-2dc8e2ab7ddc/download/redma_2023_05.csv')

# %%
df_redma
# Out:
#           fecha    PbPST       PM10       PM25         PST
# 0    2015-01-06  0.01645  37.625000  20.428571   97.500000
# 1    2015-01-12  0.02672  64.000000  33.285714  118.800000
# 2    2015-01-18  0.01704  48.750000  23.166667   99.200000
# 3    2015-01-24  0.01814  55.625000  24.166667  115.200000
# 4    2015-01-30  0.01896  56.750000  25.833333  127.400000
# ..          ...      ...        ...        ...         ...
# 507  2023-05-06      NaN  63.142857  27.000000  140.000000
# 508  2023-05-12      NaN  49.571429  25.000000  116.000000
# 509  2023-05-18      NaN  42.600000  19.600000   91.500000
# 510  2023-05-24      NaN  46.142857  23.333333   92.666667
# 511  2023-05-30      NaN  39.125000  18.666667   86.000000
#
# [512 rows x 5 columns]

# %%
from hashlib import sha1

def compute_hash(email):
    return sha1(email.encode('utf-8')).hexdigest()

def compute_certificate_id(email):
    email_clean = email.lower().strip()
    return compute_hash(email_clean + '_')

# %%
cohort = 2024
course = 'dezoomcamp'
your_id = compute_certificate_id('kiramishima@outlook.com')
url = f"https://certificate.datatalks.club/{course}/{cohort}/{your_id}.pdf"
print(url)
# Out:
# https://certificate.datatalks.club/dezoomcamp/2024/76a8a824601a2fc5b4833741e238851ef5604702.pdf
