# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df_tiraderos = pd.read_csv('https://datos.cdmx.gob.mx/dataset/c5a40bb7-241c-4bb0-8a59-6218526ba01c/resource/7041d302-e17b-4137-94a7-383b6b713761/download/tiraderos-clandestinos-al-cierre-de-2017.csv')
df_tiraderos
# Out:
#         id  column_1  fid  id_sedema  no_alcaldi       alcaldia  direccion  \
# 0        0         6    6        567          14  Benito Juarez        NaN
# 1        1        41   41        402           9     Milpa Alta        NaN
# 2        2        78   78        508          11        Tlahuac        NaN
# 3        3        81   81         62           3       Coyoacan        NaN
# 4        4        83   83        498          11        Tlahuac        NaN
# ...    ...       ...  ...        ...         ...            ...        ...
# 1124  1124       404  404        654          14  Benito Juarez        NaN
# 1125  1125       405  405        589          14  Benito Juarez        NaN
# 1126  1126       416  416        271           7     Iztapalapa        NaN
# 1127  1127       474  474        249           7     Iztapalapa        NaN
# 1128  1128       489  489        135           6      Iztacalco        NaN
#
#       tipo_tirad                                              calle  no_ext  \
# 0            NaN  Municipio Libre Es2Quina Miraflores, Colonia P...     NaN
# 1            NaN            Av. Hifalgo Y 2Ç÷ Cjon De Independencia     NaN
# 2            NaN                                  Angƒ??lica Paulet     NaN
# 3            NaN             Bodega De Barrido Manual Santa Cecilia     NaN
# 4            NaN                                     Av. Tl¶ÿ¶Huac     NaN
# ...          ...                                                ...     ...
# 1124         NaN     Priv. Lopez Cotilla Y Fƒ??lix Cuevas Eje 7 Sur     NaN
# 1125         NaN              Eje Central L¶ÿzaro Cardenas Y Necaxa     NaN
# 1126         NaN    Canal De Chalco Esq. Calle 7, Entre Calle 6 Y 8     NaN
# 1127         NaN  Calle Cazuelas Entre Av. Javier Rojo G¶½mez A ...     NaN
# 1128         NaN  Camell¶½n De Lenguas Indigenas (Bodega) Casi E...     NaN
#
#       no_int                           colonia  entre_que   longitud  \
# 0        NaN                  PORTALES ORIENTE        NaN -99.139980
# 1        NaN                 SAN PEDRO ATOCPAN        NaN -99.042876
# 2        NaN                       LA NOPALERA        NaN -99.055393
# 3        NaN                   CTM SECCIÇÿN 10        NaN -99.107160
# 4        NaN                       LA NOPALERA        NaN -99.054197
# ...      ...                               ...        ...        ...
# 1124     NaN                         VALLE SUR        NaN -99.168680
# 1125     NaN                      PORTALES SUR        NaN -99.149570
# 1126     NaN             JOS¶ LÇÿPEZ PORTILLO        NaN -99.069516
# 1127     NaN  LEYES DE REFORMA (3ERA SECCIÇÿN)        NaN -99.076900
# 1128     NaN                CARLOS ZAPATA VELA        NaN -99.096981
#
#         latitud               geo_point
# 0     19.367720      19.36772,-99.13998
# 1     19.203210  19.2032099,-99.0428762
# 2     19.296997    19.296997,-99.055393
# 3     19.300200     19.3002,-99.1071599
# 4     19.302147    19.302147,-99.054197
# ...         ...                     ...
# 1124  19.371510      19.37151,-99.16868
# 1125  19.371840      19.37184,-99.14957
# 1126  19.372817  19.3728171,-99.0695157
# 1127  19.380880       19.38088,-99.0769
# 1128  19.382044  19.3820435,-99.0969809
#
# [1129 rows x 16 columns]

# %%
df_tiraderos.columns
# Out:
# Index(['id', 'column_1', 'fid', 'id_sedema', 'no_alcaldi', 'alcaldia',
#        'direccion', 'tipo_tirad', 'calle', 'no_ext', 'no_int', 'colonia',
#        'entre_que', 'longitud', 'latitud', 'geo_point'],
#       dtype='object')

# %%
df_tiraderos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1129 non-null   int64
#  1   column_1    1129 non-null   int64
#  2   fid         1129 non-null   int64
#  3   id_sedema   1129 non-null   int64
#  4   no_alcaldi  1129 non-null   int64
#  5   alcaldia    1129 non-null   object
#  6   direccion   0 non-null      float64
#  7   tipo_tirad  0 non-null      float64
#  8   calle       1129 non-null   object
#  9   no_ext      0 non-null      float64
#  10  no_int      0 non-null      float64
#  11  colonia     1122 non-null   object
#  12  entre_que   0 non-null      float64
#  13  longitud    1129 non-null   float64
#  14  latitud     1129 non-null   float64
#  15  geo_point   1129 non-null   object
# dtypes: float64(7), int64(5), object(4)
# memory usage: 141.3+ KB

# %%
df_tiraderos = [df_tiraderos.longitud.notna()]

# %%
gdf_tiraderos = gpd.read_file('../DATASETS/tiraderos_clandestinos_al_cierre_de_2017/tiraderos_clandestinos_al_cierre_de_2017.shp')
gdf_tiraderos
# Out:
#        _id    id  column_1  fid  id_sedema  no_alcaldi       alcaldia  \
# 0        1     0         6    6        567          14  Benito Juarez
# 1        2     1        41   41        402           9     Milpa Alta
# 2        3     2        78   78        508          11        Tlahuac
# 3        4     3        81   81         62           3       Coyoacan
# 4        5     4        83   83        498          11        Tlahuac
# ...    ...   ...       ...  ...        ...         ...            ...
# 1124  1125  1124       404  404        654          14  Benito Juarez
# 1125  1126  1125       405  405        589          14  Benito Juarez
# 1126  1127  1126       416  416        271           7     Iztapalapa
# 1127  1128  1127       474  474        249           7     Iztapalapa
# 1128  1129  1128       489  489        135           6      Iztacalco
#
#      direccion tipo_tirad                                              calle  \
# 0         None       None  Municipio Libre Es2Quina Miraflores, Colonia P...
# 1         None       None            Av. Hifalgo Y 2Ç÷ Cjon De Independencia
# 2         None       None                                  Ang???lica Paulet
# 3         None       None             Bodega De Barrido Manual Santa Cecilia
# 4         None       None                                     Av. Tl¶ÿ¶Huac
# ...        ...        ...                                                ...
# 1124      None       None     Priv. Lopez Cotilla Y F???lix Cuevas Eje 7 Sur
# 1125      None       None              Eje Central L¶ÿzaro Cardenas Y Necaxa
# 1126      None       None    Canal De Chalco Esq. Calle 7, Entre Calle 6 Y 8
# 1127      None       None  Calle Cazuelas Entre Av. Javier Rojo G¶½mez A ...
# 1128      None       None  Camell¶½n De Lenguas Indigenas (Bodega) Casi E...
#
#      no_ext no_int                           colonia entre_que  \
# 0      None   None                  PORTALES ORIENTE      None
# 1      None   None                 SAN PEDRO ATOCPAN      None
# 2      None   None                       LA NOPALERA      None
# 3      None   None                   CTM SECCIÇÿN 10      None
# 4      None   None                       LA NOPALERA      None
# ...     ...    ...                               ...       ...
# 1124   None   None                         VALLE SUR      None
# 1125   None   None                      PORTALES SUR      None
# 1126   None   None             JOS¶ LÇÿPEZ PORTILLO      None
# 1127   None   None  LEYES DE REFORMA (3ERA SECCIÇÿN)      None
# 1128   None   None                CARLOS ZAPATA VELA      None
#
#                    geo_point                    geometry
# 0         19.36772,-99.13998  POINT (-99.13998 19.36772)
# 1     19.2032099,-99.0428762  POINT (-99.04288 19.20321)
# 2       19.296997,-99.055393  POINT (-99.05539 19.29700)
# 3        19.3002,-99.1071599  POINT (-99.10716 19.30020)
# 4       19.302147,-99.054197  POINT (-99.05420 19.30215)
# ...                      ...                         ...
# 1124      19.37151,-99.16868  POINT (-99.16868 19.37151)
# 1125      19.37184,-99.14957  POINT (-99.14957 19.37184)
# 1126  19.3728171,-99.0695157  POINT (-99.06952 19.37282)
# 1127       19.38088,-99.0769  POINT (-99.07690 19.38088)
# 1128  19.3820435,-99.0969809  POINT (-99.09698 19.38204)
#
# [1129 rows x 16 columns]

# %%
gdf_tiraderos.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 1129 entries, 0 to 1128
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   _id         1129 non-null   int64
#  1   id          1129 non-null   int64
#  2   column_1    1129 non-null   int64
#  3   fid         1129 non-null   int64
#  4   id_sedema   1129 non-null   int64
#  5   no_alcaldi  1129 non-null   int64
#  6   alcaldia    1129 non-null   object
#  7   direccion   0 non-null      object
#  8   tipo_tirad  0 non-null      object
#  9   calle       1129 non-null   object
#  10  no_ext      0 non-null      object
#  11  no_int      0 non-null      object
#  12  colonia     1122 non-null   object
#  13  entre_que   0 non-null      object
#  14  geo_point   1129 non-null   object
#  15  geometry    1129 non-null   geometry
# dtypes: geometry(1), int64(6), object(9)
# memory usage: 141.3+ KB

# %%
gdf_tiraderos.describe().T
# Out:
#              count       mean         std  min    25%    50%    75%     max
# _id         1129.0  565.00000  326.058533  1.0  283.0  565.0  847.0  1129.0
# id          1129.0  564.00000  326.058533  0.0  282.0  564.0  846.0  1128.0
# column_1    1129.0  564.00000  326.058533  0.0  282.0  564.0  846.0  1128.0
# fid         1129.0  564.00000  326.058533  0.0  282.0  564.0  846.0  1128.0
# id_sedema   1129.0  565.00000  326.058533  1.0  283.0  565.0  847.0  1129.0
# no_alcaldi  1129.0   11.29318    4.666726  2.0    7.0   14.0   15.0    17.0

# %%
gdf_tiraderos.plot()
plt.show()

# %%
m = gdf_tiraderos.explore(
    column="alcaldia",
    tooltip="id", # show "BoroName" value in tooltip (on hover)
    popup=True, # show all values in popup (on click)
    tiles="CartoDB positron", # use "CartoDB positron" tiles matplotlib colormap
)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_01c046d3c1cbfcc2093f05b2c6271ede {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumpopup {
#                             margin: auto;
#                         }
#                        .foliumpopup table{
#                             margin: auto;
#                         }
#                         .foliumpopup tr{
#                             text-align: left;
#                         }
#                         .foliumpopup th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend alcaldia&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;alcaldia&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;Alvaro Obregon&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#aec7e8&#x27;&gt;&lt;/span&gt;Azcapotzalco&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff7f0e&#x27;&gt;&lt;/span&gt;Benito Juarez&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#2ca02c&#x27;&gt;&lt;/span&gt;Coyoacan&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#98df8a&#x27;&gt;&lt;/span&gt;Cuajimalpa&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#ff9896&#x27;&gt;&lt;/span&gt;Cuauhtemoc&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9467bd&#x27;&gt;&lt;/span&gt;Iztacalco&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;Iztapalapa&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#c49c94&#x27;&gt;&lt;/span&gt;Magdalena Contreras&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#e377c2&#x27;&gt;&lt;/span&gt;Miguel Hidalgo&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#7f7f7f&#x27;&gt;&lt;/span&gt;Milpa Alta&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#c7c7c7&#x27;&gt;&lt;/span&gt;Tlahuac&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#dbdb8d&#x27;&gt;&lt;/span&gt;Tlalpan&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#17becf&#x27;&gt;&lt;/span&gt;Venustiano Carranza&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;Xochimilco&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_01c046d3c1cbfcc2093f05b2c6271ede&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_01c046d3c1cbfcc2093f05b2c6271ede = L.map(
#                 &quot;map_01c046d3c1cbfcc2093f05b2c6271ede&quot;,
#                 {
#                     center: [19.339988050000002, -99.1324485],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_01c046d3c1cbfcc2093f05b2c6271ede);
#
#
#
#
#
#             var tile_layer_b
