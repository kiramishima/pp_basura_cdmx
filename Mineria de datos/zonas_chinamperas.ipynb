# %%
import pandas as pd
import geopandas as gpd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
gdf_zone_chinampas = gpd.read_file('https://datos.cdmx.gob.mx/dataset/b668f9d7-1ab9-40ed-9fcb-07781d790203/resource/343e9f04-816c-4925-a57c-237f8a8b3bde/download/zona-chinampera-y-humedales-principales-cuerpos-de-agua.json')

# %%
gdf_zone_chinampas.head()
# Out:
#    id clave                    nombre condicion  \
# 0   1     A  Chinampera de Xochimilco  Chinampa
# 1   2     B     Chinampera de Tláhuac  Chinampa
# 2   3     C      Humedales de Tláhuac   Humedal
# 3   4     D     Chinampera de Mixquic  Chinampa
#
#                                             geometry
# 0  POLYGON ((-99.11116 19.27062, -99.10981 19.277...
# 1  POLYGON ((-99.02520 19.27060, -99.02425 19.273...
# 2  POLYGON ((-98.97456 19.29215, -98.96799 19.289...
# 3  POLYGON ((-98.97731 19.23402, -98.95725 19.228...

# %%
gdf_zone_chinampas.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         4 non-null      int64
#  1   clave      4 non-null      object
#  2   nombre     4 non-null      object
#  3   condicion  4 non-null      object
#  4   geometry   4 non-null      geometry
# dtypes: geometry(1), int64(1), object(3)
# memory usage: 292.0+ bytes

# %%
m = gdf_zone_chinampas.explore(
    column="condicion",
    tooltip="clave", # show "BoroName" value in tooltip (on hover)
    popup=True, # show all values in popup (on click)
    tiles="CartoDB positron", # use "CartoDB positron" tiles matplotlib colormap
)

# %%
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
gdf_zone_chinampas = gdf_zone_chinampas.to_crs({'init': 'epsg:3857'})

# %%
gdf_zone_chinampas.area
# Out:
# 0    7.891379e+06
# 1    1.074553e+06
# 2    4.772782e+06
# 3    1.861049e+06
# dtype: float64
